# %%
import warnings; warnings.simplefilter('ignore')
# Import relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import pandas_profiling as prof
import pivottablejs as pvt
import datetime as dt
import os
# %matplotlib inline

# %%
df=pd.read_excel(r'C:\Users\kumar.vishwesh\Music\KV\Bosch\DF_M.xlsx')

# %%
df.head()
# Out:
#    Plnt Batch      Material  From Date    To Date            Opening Stock  \
# 0  9020    ZI  M303.160.117 2018-01-01 2018-01-15                      175
# 1  9020    ZN  M303.160.117 2018-01-01 2018-01-15                        0
# 2  9020    ZI  M303.160.117 2018-01-15 2018-01-31                       46
# 3  9020    ZN  M303.160.117 2018-01-15 2018-01-31                        0
# 4  9020    ZI  M303.160.117 2018-02-01 2018-02-15                       48
#
#        Total Receipt Qties   Total Issue Quantities   X  \
# 0                      396                     -525 NaN
# 1                        0                        0 NaN
# 2                      552                     -550 NaN
# 3                       98                        0 NaN
# 4                      503                     -442 NaN
#
#    Demand= abs(Total Issue Quantities)+X  Inventory=F+G-J  \
# 0                                    NaN              NaN
# 1                                    NaN              NaN
# 2                                    NaN              NaN
# 3                                    NaN              NaN
# 4                                    NaN              NaN
#
#              Closing Stock BUn  Average Cons    Avj repl
# 0                       46  PC    276.083333  278.229167
# 1                        0  PC    276.083333  278.229167
# 2                       48  PC    276.083333  278.229167
# 3                       98  PC    276.083333  278.229167
# 4                      109  PC    276.083333  278.229167

# %%
df.describe()
# Out:
#          Plnt            Opening Stock      Total Receipt Qties  \
# count   240.0               240.000000               240.000000
# mean   9020.0               175.400000               183.379167
# std       0.0               137.138137               183.323553
# min    9020.0                 0.000000                 0.000000
# 25%    9020.0                60.000000                 0.000000
# 50%    9020.0               150.000000               142.000000
# 75%    9020.0               275.250000               302.500000
# max    9020.0               573.000000               761.000000
#
#         Total Issue Quantities    X  Demand= abs(Total Issue Quantities)+X  \
# count               240.000000  0.0                                    0.0
# mean               -186.204167  NaN                                    NaN
# std                 177.741185  NaN                                    NaN
# min                -761.000000  NaN                                    NaN
# 25%                -307.250000  NaN                                    NaN
# 50%                -121.000000  NaN                                    NaN
# 75%                 -48.250000  NaN                                    NaN
# max                   0.000000  NaN                                    NaN
#
#        Inventory=F+G-J            Closing Stock  Average Cons    Avj repl
# count              0.0               240.000000    240.000000  240.000000
# mean               NaN               172.575000    186.204167  183.379167
# std                NaN               134.831068     63.715335   65.972588
# min                NaN                 0.000000    112.520833  111.916667
# 25%                NaN                59.750000    123.770833  113.770833
# 50%                NaN               149.000000    179.833333  177.729167
# 75%                NaN               272.000000    238.812500  235.250000
# max                NaN               573.000000    276.083333  278.229167

# %%
df.nunique()
# Out:
# Plnt                                       1
# Batch                                      2
# Material                                   5
# From Date                                 24
# To Date                                   24
#           Opening Stock                  142
#     Total Receipt Qties                  125
#  Total Issue Quantities                  140
# X                                          0
# Demand= abs(Total Issue Quantities)+X      0
# Inventory=F+G-J                            0
#           Closing Stock                  138
# BUn                                        1
# Average Cons                               5
# Avj repl                                   5
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 15 columns):
# Plnt                                     240 non-null int64
# Batch                                    240 non-null object
# Material                                 240 non-null object
# From Date                                240 non-null datetime64[ns]
# To Date                                  240 non-null datetime64[ns]
#           Opening Stock                  240 non-null int64
#     Total Receipt Qties                  240 non-null int64
#  Total Issue Quantities                  240 non-null int64
# X                                        0 non-null float64
# Demand= abs(Total Issue Quantities)+X    0 non-null float64
# Inventory=F+G-J                          0 non-null float64
#           Closing Stock                  240 non-null int64
# BUn                                      240 non-null object
# Average Cons                             240 non-null float64
# Avj repl                                 240 non-null float64
# dtypes: datetime64[ns](2), float64(5), int64(5), object(3)
# memory usage: 28.2+ KB

# %%
prof.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>15 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>240 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>20.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>28.2 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>120.3 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>5 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_          Closing Stock"><code>          Closing Stock</code></a> has 23 / 9.6% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_          Opening Stock"><code>          Opening Stock</code></a> has 22 / 9.2% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_    Total Receipt Qties"><code>    Total Receipt Qties</code></a> has 66 / 27.5% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_ Total Issue Quantities"><code> Total Issue Quantities</code></a> has 40 / 16.7% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Avj repl"><code>Avj repl</code></a> is highly correlated with <a href="#pp_var_Average Cons"><code>Average Cons</code></a> (ρ = 0.99864) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_BUn"><code>BUn</code></a> has constant value PC <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_Demand= abs(Total Issue Quantities)+X"><code>Demand= abs(Total Issue Quantities)+X</code></a> has 240 / 100.0% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Demand= abs(Total Issue Quantities)+X"><code>Demand= a

# %%
report=prof.ProfileReport(df)
