# %%
import warnings; warnings.simplefilter('ignore')
# Import relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import pandas_profiling as prof
import pivottablejs as pvt
import datetime as dt
import os
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\kumar.vishwesh\Music\KV\Bosch\bosch_agg.csv')

# %%
df.head()
# Out:
#    store Batch      Material  From Date    To Date  agg_opening_stock  \
# 0   9020    Zn  M303.160.117   1/1/2018  1/15/2018                175
# 1   9020    Zn  M303.160.117  1/15/2018  1/31/2018                 46
# 2   9020    Zn  M303.160.117   2/1/2018  2/15/2018                146
# 3   9020    Zn  M303.160.117  2/15/2018  2/28/2018                100
# 4   9020    Zn  M303.160.117   3/1/2018  3/15/2018                270
#
#    total_receipt_quantities  agg_total_issue_quantities  agg_closing_stock  \
# 0                       396                        -525                 46
# 1                       650                        -550                146
# 2                       503                        -540                109
# 3                       819                        -649                270
# 4                       384                        -592                 62
#
#   Bun  Average Cons  Avj repl
# 0  PC           552       556
# 1  PC           552       556
# ...

# %%
df.columns
# Out:
# Index(['store', 'Batch', 'Material', 'From Date', 'To Date',
#        'agg_opening_stock', 'total_receipt_quantities',
#        'agg_total_issue_quantities', 'agg_closing_stock', 'Bun',
#        'Average Cons', 'Avj repl'],
#       dtype='object')

# %%
df=df[['Material','To Date','agg_total_issue_quantities']]

# %%
df.head()
# Out:
#        Material    To Date  agg_total_issue_quantities
# 0  M303.160.117  1/15/2018                        -525
# 1  M303.160.117  1/31/2018                        -550
# 2  M303.160.117  2/15/2018                        -540
# 3  M303.160.117  2/28/2018                        -649
# 4  M303.160.117  3/15/2018                        -592

# %%
df['agg_total_issue_quantities']=abs(df.agg_total_issue_quantities)

# %%
df.head()
# Out:
#        Material    To Date  agg_total_issue_quantities
# 0  M303.160.117  1/15/2018                         525
# 1  M303.160.117  1/31/2018                         550
# 2  M303.160.117  2/15/2018                         540
# 3  M303.160.117  2/28/2018                         649
# 4  M303.160.117  3/15/2018                         592

# %%
df.nunique()
# Out:
# Material                        6
# To Date                        24
# agg_total_issue_quantities    129
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
# Material                      144 non-null object
# To Date                       144 non-null object
# agg_total_issue_quantities    144 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 3.5+ KB

# %% [markdown]
# Collective report for all medium pace products

# %%
prof.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
report=prof.ProfileReport(df)

# %%
report.to_file()

# %%
df_1=df[df['Material']=='M303.160.117']

# %% [markdown]
# Report for Material named 'M303.160.117'

# %%
prof.ProfileReport(df_1)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
report2=prof.ProfileReport(df_1)
report2.to_file()

# %%
df_1.columns
# Out:
# Index(['Material', 'To Date', 'agg_total_issue_quantities'], dtype='object')

# %%
from fitter import Fitter

# %%
f2 = Fitter(df['agg_total_issue_quantities'])

# %%
f2.fit()
# Out:
# Fitted alpha distribution with error=0.00010198861174329895)
# Fitted anglit distribution with error=0.00010136088413629245)
# Fitted arcsine distribution with error=0.00019955457909453392)
# Fitted argus distribution with error=0.00014006178295893274)
# Fitted beta distribution with error=9.45594914108446e-05)
# Fitted betaprime distribution with error=0.00010170395535476689)
# Fitted bradford distribution with error=0.00011563957424784594)
# Fitted burr distribution with error=0.0005772073232726083)
# Fitted burr12 distribution with error=0.0006801922477784531)
# Fitted cauchy distribution with error=0.00012102627088693001)
# Fitted chi distribution with error=0.00027038691487749734)
# Fitted chi2 distribution with error=0.00010225005071321884)
# Fitted cosine distribution with error=0.00010053009552994949)
# Fitted crystalball distribution with error=0.00010430603873517041)
# Fitted dgamma distribution with error=0.00010102992799730916)
# ...

# %% [markdown]
# Distribution of all medium moving products

# %%
f2.summary()
# Out:
#                  sumsquare_error
# johnsonsb               0.000094
# beta                    0.000095
# triang                  0.000095
# tukeylambda             0.000095
# genhalflogistic         0.000096

# %%
f = Fitter(df_1['agg_total_issue_quantities'])

# %%
f.fit()
# Out:
# Fitted alpha distribution with error=0.0038636097741312635)
# Fitted anglit distribution with error=0.0038701616961230503)
# Fitted arcsine distribution with error=0.004078040255068758)
# Fitted argus distribution with error=0.0038489602969131705)
# Fitted beta distribution with error=0.0039191280696971005)
# Fitted betaprime distribution with error=0.003874594949817044)
# Fitted bradford distribution with error=0.0039356343867963575)
# Fitted burr distribution with error=0.0040055655298117145)
# Fitted burr12 distribution with error=0.004494925117749729)
# Fitted cauchy distribution with error=0.003879085845474038)
# Fitted chi distribution with error=0.0038479668928987124)
# Fitted chi2 distribution with error=0.003849728226154807)
# Fitted cosine distribution with error=0.0038537321094903104)
# Fitted crystalball distribution with error=0.0038438434097538563)
# Fitted dgamma distribution with error=0.003836039111695701)
# ...

# %% [markdown]
# Distribution of single material named 'M303.160.117'

# %%
f.summary()
# Out:
#              sumsquare_error
# dweibull            0.003787
# mielke              0.003834
# tukeylambda         0.003835
# dgamma              0.003836
# loggamma            0.003838
